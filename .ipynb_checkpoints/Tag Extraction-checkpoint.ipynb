# %%
#jupyter Notebook designed to expose "tags" from a table obtained from Kaggle that exhibits youtube information
#

# %%
#Import dependencies
import pandas as pd
import os

# %%
#Read CSV File and create a dataframe
y_d6 = pd.read_csv("Resources/MXvideos.csv",encoding='latin1')

#)
#data=ps.read_csv(r"C:\Users\akashkumar\Downloads\02_toupload_wub8x\02_toupload\worldcities.csv",encoding='latin1')

# %%
y_d4
# Out:
#           video_id trending_date  \
# 0      SbOwzAl9ZfQ      17.14.11
# 1      klOV6Xh-DnI      17.14.11
# 2      6L2ZF7Qzsbk      17.14.11
# 3      hcY52MFWMDM      17.14.11
# 4      _OXDcGPVAa4      17.14.11
# ...            ...           ...
# 40446  r63VBOagGAo      18.14.06
# 40447  i7r_kMbyngk      18.14.06
# 40448  _jnwjdMe3Zo      18.14.06
# 40449  pAH9omNAWA4      18.14.06
# 40450  dj5Z4jTE3-c      18.14.06
#
#                                                    title  \
# 0                         CapÃ­tulo 12 | MasterChef 2017
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2               LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                  ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# 40448  Maire usa una blusa kawaiii Â¿adorable o ridÃ­...
# 40449       La Jefa del CampeÃ³n - CapÃ­tulo 2 Parte 3/4
# 40450  Â¿POR QUÃ SHANKS ES TAN RESPETADO POR TODOS E...
#
#                    channel_title  category_id              publish_time  \
# 0                MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1       Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2      El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                       Casanare           25  2017-11-13T03:47:10.000Z
# 4                          Musas           26  2017-11-13T19:17:48.000Z
# ...                          ...          ...                       ...
# 40446           FPFutebolOficial           17  2018-06-13T13:11:56.000Z
# 40447                        AMX           25  2018-06-13T01:15:08.000Z
# 40448             Historias Wink           24  2018-06-13T15:08:53.000Z
# 40449                  Tele Time           22  2018-06-13T02:22:33.000Z
# 40450                GolD Nakama           24  2018-06-13T19:01:52.000Z
#
#                                                     tags   views  likes  \
# 0      MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  310130   4182
# 1                                        La Voz Mexico 7  104972    271
# 2      Chumel Torres|"El Pulso de la Republica"|"noti...  136064  10105
# 3             temblor|"costa rica"|"sismo en costa rica"   96153    378
# 4      MUSAS|"lesslie"|"karen"|"hacks"|"perros"|"dogs...  499965  57781
# ...                                                  ...     ...    ...
# 40446  Canal|"Oficial"|"da"|"FederaÃ§Ã£o"|"Portuguesa...  653114  65639
# 40447  AMLO|"morena"|"polÃ­tica"|"PRI"|"PAN"|"PRD"|"L...  121674   3558
# 40448  maire|"maire vs el internet"|"maire vs interne...   14067    538
# 40449                                             [none]   22898     94
# 40450                                             [none]  108936   5398
#
#        dislikes  comment_count  \
# 0           361           1836
# 1           174            369
# 2           266            607
# 3           171            208
# 4           681           7428
# ...         ...            ...
# 40446       547           3826
# 40447        58            491
# 40448         6             90
# 40449        11              3
# 40450       148            993
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/SbOwzAl9ZfQ/default.jpg              False
# 1      https://i.ytimg.com/vi/klOV6Xh-DnI/default.jpg              False
# 2      https://i.ytimg.com/vi/6L2ZF7Qzsbk/default.jpg              False
# 3      https://i.ytimg.com/vi/hcY52MFWMDM/default.jpg              False
# 4      https://i.ytimg.com/vi/_OXDcGPVAa4/default.jpg              False
# ...                                               ...                ...
# 40446  https://i.ytimg.com/vi/r63VBOagGAo/default.jpg              False
# 40447  https://i.ytimg.com/vi/i7r_kMbyngk/default.jpg              False
# 40448  https://i.ytimg.com/vi/_jnwjdMe3Zo/default.jpg              False
# 40449  https://i.ytimg.com/vi/pAH9omNAWA4/default.jpg              False
# 40450  https://i.ytimg.com/vi/dj5Z4jTE3-c/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40446             False                   False
# 40447             False                   False
# 40448             False                   False
# 40449             False                   False
# 40450             False                   False
#
#                                              description
# 0      Disfruta la presencia del Chef Torreblanca en ...
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2      La canciÃ³n del principio se llama âEste esp...
# 3      El video es de un Walmart en el pais centroame...
# 4      MI HERMANO NARRA MI RUTINA DE MAQUILLAJE\nhttp...
# ...                                                  ...
# 40446  Portugal's Football Team Official SongLyrics: ...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# 40448  Maire usa una blusa kawaii de Alicia en el paÃ...
# 40449                                                NaN
# 40450  Hoy os traigo el preguntas y respuestas 104 de...
#
# [40451 rows x 16 columns]

# %%
#Clean dataframe from special characters to make it readable, manageable and queriable
#characters in spanish aren't readable: ñ - , á - , é - , í - , ó - , ú - 
#re-write characters to n,a,e,i,o,u
#á & Á
y_d['title'] = y_d['title'].str.replace('ГЎ','á')
y_d['title'] = y_d['title'].str.replace('ГЌ','Á')
#é & É
y_d['title'] = y_d['title'].str.replace('Г©','é')
y_d['title'] = y_d['title'].str.replace('Г‰','É')
#í & Í
#y_d['title'] = y_d['title'].str.replace('Ã','í')
y_d['title'] = y_d['title'].str.replace('Г','í')
y_d['title'] = y_d['title'].str.replace('ГЌ','Í')
#ó & Ó
y_d['title'] = y_d['title'].str.replace('Гі','ó') 
y_d['title'] = y_d['title'].str.replace('Г“','Ó')
#ú & Ú
y_d['title'] = y_d['title'].str.replace('Гє','ú')
#ñ & Ñ
y_d['title'] = y_d['title'].str.replace('Г±','ñ')
y_d['title'] = y_d['title'].str.replace('Г‘','Ñ')
#¡
y_d['title'] = y_d['title'].str.replace('ВЎ','¡')
#¿
y_d['title'] = y_d['title'].str.replace('Вї','¿')

# %%
df_f = y_d6.filter(["video_id", "tags"], axis = 1)

# %%
df_i = df_f.set_index("video_id")

# %%
df_i
# Out:
#                                                           tags
# video_id
# SbOwzAl9ZfQ  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...
# klOV6Xh-DnI                                    La Voz Mexico 7
# 6L2ZF7Qzsbk  Chumel Torres|"El Pulso de la Republica"|"noti...
# hcY52MFWMDM         temblor|"costa rica"|"sismo en costa rica"
# _OXDcGPVAa4  MUSAS|"lesslie"|"karen"|"hacks"|"perros"|"dogs...
# ...                                                        ...
# r63VBOagGAo  Canal|"Oficial"|"da"|"FederaÃ§Ã£o"|"Portuguesa...
# i7r_kMbyngk  AMLO|"morena"|"polÃ­tica"|"PRI"|"PAN"|"PRD"|"L...
# _jnwjdMe3Zo  maire|"maire vs el internet"|"maire vs interne...
# pAH9omNAWA4                                             [none]
# dj5Z4jTE3-c                                             [none]
#
# [40451 rows x 1 columns]

# %%
#Split tag column contents
df=df_i["tags"].str.split('|', expand = True)
#df2= y_d6["video_id"]
#df3= y_d6["category_id"]

# %%
df
df.reset_index(level=0, inplace=True)

# %%
#import numpy as np
#df.columns = [x.strip().replace('"', '') for x in df.columns]


df["1"] = df["1"].str.replace('"','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-7a2287ac8896> in <module>
#       3
#       4
# ----> 5 df["1"] = df["1"].str.replace('"','')
#       6
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'

# %%
#Export dataframe to Postgres
df
# Out:
#           video_id                       0                           1  \
# 0      SbOwzAl9ZfQ  MasterChef Junior 2017                 "TV Azteca"
# 1      klOV6Xh-DnI         La Voz Mexico 7                        None
# 2      6L2ZF7Qzsbk           Chumel Torres  "El Pulso de la Republica"
# 3      hcY52MFWMDM                 temblor                "costa rica"
# 4      _OXDcGPVAa4                   MUSAS                   "lesslie"
# ...            ...                     ...                         ...
# 40446  r63VBOagGAo                   Canal                   "Oficial"
# 40447  i7r_kMbyngk                    AMLO                    "morena"
# 40448  _jnwjdMe3Zo                   maire      "maire vs el internet"
# 40449  pAH9omNAWA4                  [none]                        None
# 40450  dj5Z4jTE3-c                  [none]                        None
#
#                            2              3                4  \
# 0                  "recetas"       "cocina"  "Anette Michel"
# 1                       None           None             None
# 2                 "noticias"         "news"         "mexico"
# 3      "sismo en costa rica"           None             None
# 4                    "karen"        "hacks"         "perros"
# ...                      ...            ...              ...
# 40446                   "da"  "FederaÃ§Ã£o"     "Portuguesa"
# 40447            "polÃ­tica"          "PRI"            "PAN"
# 40448    "maire vs internet"   "maire wink"     "maire_wink"
# 40449                   None           None             None
# 40450                   None           None             None
#
#                       5                      6                  7  \
# 0      "Betty VÃ¡zquez"        "Benito Molina"  "AdriÃ¡n Herrera"
# 1                  None                   None               None
# 2                 "pri"                  "pan"              "prd"
# 3                  None                   None               None
# 4                "dogs"               "trucos"   "los polinesios"
# ...                 ...                    ...                ...
# 40446              "de"              "Futebol"        "SeleÃ§Ã£o"
# 40447             "PRD"       "LÃ³pez Obrador"               None
# 40448          "kawaii"  "alice in wonderland"   "ropa de disney"
# 40449              None                   None               None
# 40450              None                   None               None
#
#                                             8  ...    69    70    71    72  \
# 0                        "master chef mexico"  ...  None  None  None  None
# 1                                        None  ...  None  None  None  None
# 2                                    "morena"  ...  None  None  None  None
# 3                                        None  ...  None  None  None  None
# 4                                      "aria"  ...  None  None  None  None
# ...                                       ...  ...   ...   ...   ...   ...
# 40446                          "shawn mendes"  ...  None  None  None  None
# 40447                                    None  ...  None  None  None  None
# 40448  "Alicia en el paÃ­s de las maravillas"  ...  None  None  None  None
# 40449                                    None  ...  None  None  None  None
# 40450                                    None  ...  None  None  None  None
#
#          73    74    75    76    77    78
# 0      None  None  None  None  None  None
# 1      None  None  None  None  None  None
# 2      None  None  None  None  None  None
# 3      None  None  None  None  None  None
# 4      None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...
# 40446  None  None  None  None  None  None
# 40447  None  None  None  None  None  None
# 40448  None  None  None  None  None  None
# 40449  None  None  None  None  None  None
# 40450  None  None  None  None  None  None
#
# [40451 rows x 80 columns]
